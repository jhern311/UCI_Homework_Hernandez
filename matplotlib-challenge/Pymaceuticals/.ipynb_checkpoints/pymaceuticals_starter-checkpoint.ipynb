# %% [markdown]
# ## Observations and Insights

# %%
#  1.) Capomulin had the highest number of mice to complete the study with 230. Total mice in this study was 248.
#  2.) There is a strong correlation between mouse weight and tumor volume which suggests that the greater the weight the the higher the tumor volume.
#  3.) Capomulin and Ramicane led the pack in the reduction of tumor size through out the duration of the study. 
#  4.)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from sklearn import datasets

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_study = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="outer")

# Display the data table for preview
combined_study
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
number_mice = combined_study['Mouse ID'].value_counts()
raw_number_mice = len(number_mice)
raw_number_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_id = combined_study.loc[combined_study.duplicated(subset=['Mouse ID', 'Timepoint',]),'Mouse ID'].unique()
dup_mouse_id = pd.DataFrame({"Mouse ID": duplicate_id})
dup_mouse_id
# Out:
#   Mouse ID
# 0     g989

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_df = combined_study[combined_study['Mouse ID'].isin(duplicate_id)]
duplicate_mouse_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
# clean_dataset = combined_study.drop(combined_study.index[[908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920]])
# clean_dataset
clean_dataset = combined_study.loc[combined_study["Mouse ID"] != "g989"]
clean_dataset
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_mouse_id = clean_dataset['Mouse ID'].value_counts()
actual_mouse_count = len(clean_mouse_id)
actual_mouse_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

regimen_mean = clean_dataset.groupby('Drug Regimen').mean()['Tumor Volume (mm3)']
regimen_median = clean_dataset.groupby('Drug Regimen').median()['Tumor Volume (mm3)']
regimen_var = clean_dataset.groupby('Drug Regimen').var()['Tumor Volume (mm3)']  
regimen_std = clean_dataset.groupby('Drug Regimen').std()['Tumor Volume (mm3)']
regimen_sem = clean_dataset.groupby('Drug Regimen').sem()['Tumor Volume (mm3)']

# Format decimal places
pd.options.display.float_format = '{:,.2f}'.format

statistics_summary_df = pd.DataFrame({'Mean':regimen_mean, 'Median':regimen_median, 'Variance':regimen_var, 
                                      'Standard Deviation':regimen_std, 'Standard Error of Mean':regimen_sem})
statistics_summary_df
# Out:
#               Mean  Median  Variance  Standard Deviation  \
# Drug Regimen
# Capomulin    40.68   41.56     24.95                4.99
# Ceftamin     52.59   51.78     39.29                6.27
# Infubinol    52.88   51.82     43.13                6.57
# Ketapril     55.24   53.70     68.55                8.28
# Naftisol     54.33   52.51     66.17                8.13
# Placebo      54.03   52.29     61.17                7.82
# Propriva     52.32   50.45     43.85                6.62
# Ramicane     40.22   40.67     23.49                4.85
# Stelasyn     54.23   52.43     59.45                7.71
# Zoniferol    53.24   51.82     48.53                6.97
#
#               Standard Error of Mean
# Drug Regimen
# Capomulin                       0.33
# Ceftamin                        0.47
# Infubinol                       0.49
# Ketapril                        0.60
# Naftisol                        0.60
# Placebo                         0.58
# Propriva                        0.54
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
single_group_by = clean_dataset.groupby('Drug Regimen')

# Format decimal places
pd.options.display.float_format = '{:,.2f}'.format

# Use aggregate method to produce summary statistics
summary_stats_table_2 = single_group_by.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]
summary_stats_table_2
# Out:
#               mean  median   var  std  sem
# Drug Regimen
# Capomulin    40.68   41.56 24.95 4.99 0.33
# Ceftamin     52.59   51.78 39.29 6.27 0.47
# Infubinol    52.88   51.82 43.13 6.57 0.49
# Ketapril     55.24   53.70 68.55 8.28 0.60
# Naftisol     54.33   52.51 66.17 8.13 0.60
# Placebo      54.03   52.29 61.17 7.82 0.58
# Propriva     52.32   50.45 43.85 6.62 0.54
# Ramicane     40.22   40.67 23.49 4.85 0.32
# Stelasyn     54.23   52.43 59.45 7.71 0.57
# Zoniferol    53.24   51.82 48.53 6.97 0.52

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
unique_mice_treated = clean_dataset.groupby(["Drug Regimen"]).count()["Mouse ID"] 


mice_tested_bar_plot = unique_mice_treated.plot.bar(figsize=(15,10), color='b',fontsize = 14, rot = 0)

plt.xlabel("Drug Regimen",fontsize = 14)
plt.ylabel("Number of Mice",fontsize = 14)
plt.title("Number of Mice per Treatment",fontsize = 20)

plt.tight_layout()
plt.show()

mice_tested_bar_plot
# Out:
# <AxesSubplot:title={'center':'Number of Mice per Treatment'}, xlabel='Drug Regimen', ylabel='Number of Mice'>

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
mice_list =(clean_dataset.groupby(["Drug Regimen"])["Mouse ID"].count()).tolist()
mice_list
# Out:
# [230, 178, 178, 188, 186, 181, 148, 228, 181, 182]

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.

x_axis = np.arange(len(unique_mice_treated))
fig1, ax1 = plt.subplots(figsize=(15, 10))
plt.bar(x_axis, mice_list, color='b', alpha=0.8, align='center')

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol'],  rotation='horizontal')

plt.xlim(-0.75, len(x_axis)-0.25)

plt.ylim(0, max(mice_list)+10)

plt.title("Number of Mice per Treatment",fontsize = 20)
plt.xlabel("Drug Regimen",fontsize = 14)
plt.ylabel("Number of Mice",fontsize = 14)
# Out:
# Text(0, 0.5, 'Number of Mice')

# %%
#  Group by gender and get the number to plot
mice_by_gender = clean_dataset.groupby(["Mouse ID","Sex"])
mice_by_gender
gender_df = pd.DataFrame(mice_by_gender.size())

# Create the dataframe with total count of Female and Male mice
mouse_gender = pd.DataFrame(gender_df.groupby(["Sex"]).count())
mouse_gender.columns = ["Total Count"]

# create and format the percentage of female vs male
mouse_gender["Percentage of Sex"] = (100*(mouse_gender["Total Count"]/mouse_gender["Total Count"].sum()))

# format the "Percentage of Sex" column


# gender_df
mouse_gender
# Out:
#         Total Count  Percentage of Sex
# Sex
# Female          123              49.60
# Male            125              50.40

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
colors = ['pink', 'blue']
explode = (0.1, 0)
plot = mouse_gender.plot.pie(y='Total Count',figsize=(15,10), colors = colors, startangle=140, explode = explode, autopct="%1.1f%%")

plt.title('Gender Distribution of Mouse Population for Treatment',fontsize = 20)

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Create Labels for the sections of the pie
labels = ["Female","Male"]

#List the values of each section of the pie chart
sizes = [49.60,50.40]

#Set colors for each section of the pie
colors = ['pink', 'blue']

#Determine which section of the circle to detach
explode = (0.1, 0)

#Create the pie chart based upon the values 
fig1, ax1 = plt.subplots(figsize=(20, 10))
plt.pie(sizes, explode=explode,labels=labels, colors=colors, autopct="%1.1f%%", startangle=125)
plt.title('Gender Distribution of Mouse Population for Treatment',fontsize = 20)


plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_timepoint = clean_dataset.groupby("Mouse ID").max()["Timepoint"] 
max_df = max_timepoint.reset_index()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merge_df = pd.merge(max_df, clean_dataset, on=["Mouse ID", "Timepoint"], how="left")
merge_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0                 67.97                 2
# 1                 65.53                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
drug_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_volume = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for x in drug_list:
   
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    drug_volume = merge_df.loc[merge_df["Drug Regimen"] == x]["Tumor Volume (mm3)"]
    
    # add subset 
   
    tumor_volume.append(drug_volume)   

    # Determine outliers using upper and lower bounds
    
    quartiles = drug_volume.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    drug_outlier = drug_volume.loc[(drug_volume < lower_bound) | (drug_volume > upper_bound)]
    print(x, drug_outlier)
# Out:
# Capomulin Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol 31   36.32
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
plt.boxplot(tumor_volume, labels=drug_list)
plt.ylabel('Final Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_vol_timepoint = clean_dataset.loc[clean_dataset["Drug Regimen"] == "Capomulin"]
capomulin_mouse = capomulin_vol_timepoint.loc[capomulin_vol_timepoint["Mouse ID"] == "s185"]
capomulin_mouse
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
# 15     s185    Capomulin  Female           3          17         25
# 16     s185    Capomulin  Female           3          17         30
# 17     s185    Capomulin  Female           3          17         35
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10               45.00                 0
# 11               43.88                 0
# 12               37.61                 0
# 13               38.18                 0
# ...

# %%
x_axis = capomulin_mouse["Timepoint"]
y_axis = capomulin_mouse["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots(figsize=(15, 10))
plt.title('Capomulin Treatmeant of Mouse s185',fontsize =25)
plt.plot(x_axis, y_axis, linewidth=2, markersize=15, marker="o", color="red")
plt.xlabel('Timepoint',fontsize =14)
plt.ylabel('Tumor Volume (mm3)',fontsize =14)

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_vol_timepoint = clean_dataset.loc[clean_dataset["Drug Regimen"] == "Capomulin"]
avg_vol_wt = capomulin_vol_timepoint.groupby(["Mouse ID"]).mean()
avg_vol_wt
# Out:
#           Age_months  Weight (g)  Timepoint  Tumor Volume (mm3)  \
# Mouse ID
# b128            9.00       22.00      22.50               41.96
# b742            7.00       21.00      22.50               40.08
# f966           16.00       17.00      10.00               36.51
# g288            3.00       19.00      22.50               41.99
# g316           22.00       22.00      22.50               44.61
# i557            1.00       24.00      22.50               44.81
# i738           23.00       20.00      22.50               39.14
# j119            7.00       23.00      22.50               44.47
# j246           21.00       21.00      17.50               43.22
# l509           17.00       21.00      22.50               44.43
# l897           17.00       19.00      22.50               42.51
# m601           22.00       17.00      22.50               34.85
# m957            3.00       19.00      22.50               39.05
# ...

# %% [markdown]
# ## Correlation and Regression

# %%
fig1, ax1 = plt.subplots(figsize=(10, 5))
marker_size=10
plt.scatter(avg_vol_wt['Tumor Volume (mm3)'], avg_vol_wt['Weight (g)'], s=50, color="purple")
plt.title('Average Tumor Volume Versus Weight',fontsize =20)
plt.xlabel('Average Tumor Volume (mm3)',fontsize =14)
plt.ylabel('Weight (g)',fontsize =14)

plt.show()

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
corr = round(st.pearsonr(avg_vol_wt['Weight (g)'],avg_vol_wt['Tumor Volume (mm3)'])[0],2)
print(f"The correlation between mouse weight and average tumor volume for Caplomulin is {corr}")
# Out:
# The correlation between mouse weight and average tumor volume for Caplomulin is 0.84

# %%
# Finding linear regression line and plotting it

# Creating x-axis and y-axis values

x_values = avg_vol_wt['Tumor Volume (mm3)']
y_values = avg_vol_wt['Weight (g)']

# Plotting scatter plot and regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values, color="purple")
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(41
                      ,17),fontsize=15,color="red")
plt.title('Average Tumor Volume Versus Weight',fontsize =20)
plt.xlabel('Avg Tumor Volume',fontsize =14)
plt.ylabel('Weight (g)',fontsize =14)
plt.savefig("matplotlib")

# print(f"slope:{slope}")
# print(f"intercept:{intercept}")
# print(f"rvalue (Correlation coefficient):{rvalue}")
# print(f"r-squared: {rvalue**2}")
# print(f"stderr:{stderr}")
